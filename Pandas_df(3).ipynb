# %% [markdown]
# <a href="https://colab.research.google.com/github/ZaremaDibirova/Pandas_practise/blob/main/Pandas_df(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({'Year':[1776,1876,1821], 'Pop':[328,28,126], 'GDP':[28.5,1.7,1.22]},index=['USA','Canada','Mexico'])

# %%
df
# Out:
#         Year  Pop    GDP
# USA     1776  328  28.50
# Canada  1876   28   1.70
# Mexico  1821  126   1.22

# %%
df[df['Pop']>50]
# Out:
#         Year  Pop    GDP
# USA     1776  328  28.50
# Mexico  1821  126   1.22

# %%
df['Pop']>50
# Out:
# USA        True
# Canada    False
# Mexico     True
# Name: Pop, dtype: bool

# %%
#hansi olkeler 1800-den sonra yaranib

# %%
df[df['Year']>1800]
# Out:
#         Year  Pop   GDP
# Canada  1876   28  1.70
# Mexico  1821  126  1.22

# %%
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#odenen pulun miqdari 40-dan yuksek olanlari gosterin

# %%
df[df['total_bill']>40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# ...

# %%
#cinsi qadin olan butun musterileri gosterin

# %%
df[df['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#Cinsi kisi ve odediyi tips miqdari 5-den yuksek olanlari goster

# %%
df[(df['sex']=='Female') & (df['tip']>5)]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 52        34.81  5.20  Female     No   Sun  Dinner     4              8.70
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 155       29.85  5.14  Female     No   Sun  Dinner     5              5.97
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3              9.39
#
#           Payer Name         CC Number Payment ID
# 52      Emily Daniel  4291280793094374    Sun6165
# 85       Shawna Cook  6011787464177340   Thur7972
# 155   Madison Wilson  4210875236164664    Sun9176
# 214  Marissa Jackson  4922302538691962    Sat3374

# %%
#Gunu Bazar ve odenis miqdari 30-dan yuksek olan setirleri gosterin

# %%
df[(df['day']=='Sun') & (df['total_bill']>30)].head(10)
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 4577817359320969       35.26  5.00  Female     No  Sun  Dinner     4
# 503846761263           30.40  5.60    Male     No  Sun  Dinner     4
# 3552002592874186       32.40  6.00    Male     No  Sun  Dinner     4
# 4291280793094374       34.81  5.20  Female     No  Sun  Dinner     4
# 3572865915176463       38.07  4.00    Male     No  Sun  Dinner     3
# 3523151482063321       48.17  5.00    Male     No  Sun  Dinner     6
# 3566285921227119       31.71  4.50    Male     No  Sun  Dinner     4
# 3577115550328507       31.85  3.18    Male    Yes  Sun  Dinner     2
# 370307040837149        32.90  3.11    Male    Yes  Sun  Dinner     2
# 346656312114848        34.63  3.55    Male    Yes  Sun  Dinner     2
#
#                   price_person       Payer Name Payment ID
# CC Number
# 4577817359320969          8.82     Diane Macias    Sun6686
# 503846761263              7.60      Todd Cooper    Sun2274
# ...

# %%
#Senbe ve bazar gunleri gelen musteri melumatlarini getirin

# %%
df[(df['day']=='Sat') | (df['day']=='Sun')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[df['day'].isin(['Sat','Sun'])].head()
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 3560325168603410       16.99  1.01  Female     No  Sun  Dinner     2
# 4478071379779230       10.34  1.66    Male     No  Sun  Dinner     3
# 6011812112971322       21.01  3.50    Male     No  Sun  Dinner     3
# 4676137647685994       23.68  3.31    Male     No  Sun  Dinner     2
# 4832732618637221       24.59  3.61  Female     No  Sun  Dinner     4
#
#                   price_person          Payer Name Payment ID
# CC Number
# 3560325168603410          8.49  Christy Cunningham    Sun2959
# 4478071379779230          3.45      Douglas Tucker    Sun4608
# 6011812112971322          7.00      Travis Walters    Sun4458
# 4676137647685994         11.84    Nathaniel Harris    Sun5260
# 4832732618637221          6.15        Tonya Carter    Sun2251

# %%
df[df['day'] !='Sun'].head()
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 19       20.65  3.35    Male     No  Sat  Dinner     3              6.88
# 20       17.92  4.08    Male     No  Sat  Dinner     2              8.96
# 21       20.29  2.75  Female     No  Sat  Dinner     2             10.14
# 22       15.77  2.23  Female     No  Sat  Dinner     2              7.88
# 23       39.42  7.58    Male     No  Sat  Dinner     4              9.86
#
#          Payer Name         CC Number Payment ID
# 19    Timothy Oneal  6568069240986485    Sat9213
# 20      Thomas Rice  4403296224639756    Sat1709
# 21  Natalie Gardner  5448125351489749    Sat9618
# 22   Ashley Shelton  3524119516293213    Sat9786
# 23   Lance Peterson  3542584061609808     Sat239

# %%
#Siqaret cekmeyen,cinsi kisi olan ve seher yemeyi yemeye gelen musteri melumatlarini goster

# %%
df[(df['smoker']=='No') & (df['sex']=='Male') & (df['time']=='Dinner')].head(10)
# Out:
#     total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1        10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5        25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00  Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12  Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96  Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23  Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71  Male     No  Sun  Dinner     2              5.14
# 12       15.42  1.57  Male     No  Sun  Dinner     2              7.71
#
#             Payer Name         CC Number Payment ID
# 1       Douglas Tucker  4478071379779230    Sun4608
# 2       Travis Walters  6011812112971322    Sun4458
# ...

# %%
df.set_index('CC Number',inplace=True)

# %%
df
# Out:
#                   total_bill   tip     sex smoker   day    time  size  \
# CC Number
# 3560325168603410       16.99  1.01  Female     No   Sun  Dinner     2
# 4478071379779230       10.34  1.66    Male     No   Sun  Dinner     3
# 6011812112971322       21.01  3.50    Male     No   Sun  Dinner     3
# 4676137647685994       23.68  3.31    Male     No   Sun  Dinner     2
# 4832732618637221       24.59  3.61  Female     No   Sun  Dinner     4
# ...                      ...   ...     ...    ...   ...     ...   ...
# 5296068606052842       29.03  5.92    Male     No   Sat  Dinner     3
# 3506806155565404       27.18  2.00  Female    Yes   Sat  Dinner     2
# 6011891618747196       22.67  2.00    Male    Yes   Sat  Dinner     2
# 4375220550950          17.82  1.75    Male     No   Sat  Dinner     2
# 3511451626698139       18.78  3.00  Female     No  Thur  Dinner     2
#
#                   price_per_person          Payer Name Payment ID
# CC Number
# ...

# %%
df.iloc[5:11]
# Out:
#                   total_bill   tip   sex smoker  day    time  size  \
# CC Number
# 213140353657882        25.29  4.71  Male     No  Sun  Dinner     4
# 2223727524230344        8.77  2.00  Male     No  Sun  Dinner     2
# 3514785077705092       26.88  3.12  Male     No  Sun  Dinner     4
# 3522866365840377       15.04  1.96  Male     No  Sun  Dinner     2
# 3532124519049786       14.78  3.23  Male     No  Sun  Dinner     2
# 566287581219           10.27  1.71  Male     No  Sun  Dinner     2
#
#                   price_per_person          Payer Name Payment ID
# CC Number
# 213140353657882               6.32          Erik Smith    Sun9679
# 2223727524230344              4.38  Kristopher Johnson    Sun5985
# 3514785077705092              6.72         Robert Buck    Sun8157
# 3522866365840377              7.52     Joseph Mcdonald    Sun6820
# 3532124519049786              7.39       Jerome Abbott    Sun3775
# 566287581219                  5.14       William Riley    Sun2546

# %%
df[(df['Payment ID']=='Sun6820') & (df['Payer Name']=='Joseph Mcdonald')]
# Out:
#                   total_bill   tip   sex smoker  day    time  size  \
# CC Number
# 3522866365840377       15.04  1.96  Male     No  Sun  Dinner     2
#
#                   price_per_person       Payer Name Payment ID
# CC Number
# 3522866365840377              7.52  Joseph Mcdonald    Sun6820

# %%
df['total_amount']=df['total_bill']+df['tip']

# %%
df.head()
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 3560325168603410       16.99  1.01  Female     No  Sun  Dinner     2
# 4478071379779230       10.34  1.66    Male     No  Sun  Dinner     3
# 6011812112971322       21.01  3.50    Male     No  Sun  Dinner     3
# 4676137647685994       23.68  3.31    Male     No  Sun  Dinner     2
# 4832732618637221       24.59  3.61  Female     No  Sun  Dinner     4
#
#                   price_per_person          Payer Name Payment ID  \
# CC Number
# 3560325168603410              8.49  Christy Cunningham    Sun2959
# 4478071379779230              3.45      Douglas Tucker    Sun4608
# 6011812112971322              7.00      Travis Walters    Sun4458
# 4676137647685994             11.84    Nathaniel Harris    Sun5260
# 4832732618637221              6.15        Tonya Carter    Sun2251
#
#                   total_amount
# CC Number
# 3560325168603410         18.00
# 4478071379779230         12.00
# ...

# %%
df.drop('total_amount',axis=1,inplace=True)

# %%
df.head()
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 3560325168603410       16.99  1.01  Female     No  Sun  Dinner     2
# 4478071379779230       10.34  1.66    Male     No  Sun  Dinner     3
# 6011812112971322       21.01  3.50    Male     No  Sun  Dinner     3
# 4676137647685994       23.68  3.31    Male     No  Sun  Dinner     2
# 4832732618637221       24.59  3.61  Female     No  Sun  Dinner     4
#
#                   price_per_person          Payer Name Payment ID
# CC Number
# 3560325168603410              8.49  Christy Cunningham    Sun2959
# 4478071379779230              3.45      Douglas Tucker    Sun4608
# 6011812112971322              7.00      Travis Walters    Sun4458
# 4676137647685994             11.84    Nathaniel Harris    Sun5260
# 4832732618637221              6.15        Tonya Carter    Sun2251

# %%
df.rename(columns={'price_per_person':'price_person'},inplace=True)

# %%
df.head()
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 3560325168603410       16.99  1.01  Female     No  Sun  Dinner     2
# 4478071379779230       10.34  1.66    Male     No  Sun  Dinner     3
# 6011812112971322       21.01  3.50    Male     No  Sun  Dinner     3
# 4676137647685994       23.68  3.31    Male     No  Sun  Dinner     2
# 4832732618637221       24.59  3.61  Female     No  Sun  Dinner     4
#
#                   price_person          Payer Name Payment ID
# CC Number
# 3560325168603410          8.49  Christy Cunningham    Sun2959
# 4478071379779230          3.45      Douglas Tucker    Sun4608
# 6011812112971322          7.00      Travis Walters    Sun4458
# 4676137647685994         11.84    Nathaniel Harris    Sun5260
# 4832732618637221          6.15        Tonya Carter    Sun2251

# %%
df.shape
# Out:
# (244, 10)

# %%
df.shape[1]
# Out:
# 10

# %%
df.shape[0]
# Out:
# 244
