# %% [markdown]
# <a href="https://colab.research.google.com/github/ZaremaDibirova/Pandas_practise_df/blob/main/Pandas_df(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Row Functions

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.set_index('Payer Name',drop=True,inplace=True)

# %%
df.head()
# Out:
#                     total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No  Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No  Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No  Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No  Sun  Dinner     4
#
#                     price_per_person         CC Number Payment ID
# Payer Name
# Christy Cunningham              8.49  3560325168603410    Sun2959
# Douglas Tucker                  3.45  4478071379779230    Sun4608
# Travis Walters                  7.00  6011812112971322    Sun4458
# Nathaniel Harris               11.84  4676137647685994    Sun5260
# Tonya Carter                    6.15  4832732618637221    Sun2251

# %%
df.loc['Douglas Tucker']
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# CC Number           4478071379779230
# Payment ID                   Sun4608
# Name: Douglas Tucker, dtype: object

# %%
df.iloc[3:5]
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Nathaniel Harris       23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter           24.59  3.61  Female     No  Sun  Dinner     4
#
#                   price_per_person         CC Number Payment ID
# Payer Name
# Nathaniel Harris             11.84  4676137647685994    Sun5260
# Tonya Carter                  6.15  4832732618637221    Sun2251

# %%
df.loc['Christy Cunningham':'Douglas Tucker']
# Out:
#                     total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No  Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No  Sun  Dinner     3
#
#                     price_per_person         CC Number Payment ID
# Payer Name
# Christy Cunningham              8.49  3560325168603410    Sun2959
# Douglas Tucker                  3.45  4478071379779230    Sun4608

# %%
df.iloc[1]
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# CC Number           4478071379779230
# Payment ID                   Sun4608
# Name: Douglas Tucker, dtype: object

# %%
df.loc['Douglas Tucker':'Tonya Carter']
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Douglas Tucker         10.34  1.66    Male     No  Sun  Dinner     3
# Travis Walters         21.01  3.50    Male     No  Sun  Dinner     3
# Nathaniel Harris       23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter           24.59  3.61  Female     No  Sun  Dinner     4
#
#                   price_per_person         CC Number Payment ID
# Payer Name
# Douglas Tucker                3.45  4478071379779230    Sun4608
# Travis Walters                7.00  6011812112971322    Sun4458
# Nathaniel Harris             11.84  4676137647685994    Sun5260
# Tonya Carter                  6.15  4832732618637221    Sun2251

# %%
df.loc[['Douglas Tucker','Tonya Carter']]
# Out:
#                 total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Douglas Tucker       10.34  1.66    Male     No  Sun  Dinner     3
# Tonya Carter         24.59  3.61  Female     No  Sun  Dinner     4
#
#                 price_per_person         CC Number Payment ID
# Payer Name
# Douglas Tucker              3.45  4478071379779230    Sun4608
# Tonya Carter                6.15  4832732618637221    Sun2251

# %%
df.iloc[[2,9]]
# Out:
#                 total_bill   tip   sex smoker  day    time  size  \
# Payer Name
# Travis Walters       21.01  3.50  Male     No  Sun  Dinner     3
# Jerome Abbott        14.78  3.23  Male     No  Sun  Dinner     2
#
#                 price_per_person         CC Number Payment ID
# Payer Name
# Travis Walters              7.00  6011812112971322    Sun4458
# Jerome Abbott               7.39  3532124519049786    Sun3775

# %%
df.drop('Douglas Tucker').head()
# Out:
#                     total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No  Sun  Dinner     2
# Travis Walters           21.01  3.50    Male     No  Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No  Sun  Dinner     4
# Erik Smith               25.29  4.71    Male     No  Sun  Dinner     4
#
#                     price_per_person         CC Number Payment ID
# Payer Name
# Christy Cunningham              8.49  3560325168603410    Sun2959
# Travis Walters                  7.00  6011812112971322    Sun4458
# Nathaniel Harris               11.84  4676137647685994    Sun5260
# Tonya Carter                    6.15  4832732618637221    Sun2251
# Erik Smith                      6.32   213140353657882    Sun9679

# %%
df.set_index('CC Number',verify_integrity=True,inplace=True)

# %%
df.iloc[10:18]
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 566287581219           10.27  1.71    Male     No  Sun  Dinner     2
# 4577817359320969       35.26  5.00  Female     No  Sun  Dinner     4
# 577040572932           15.42  1.57    Male     No  Sun  Dinner     2
# 6011163105616890       18.43  3.00    Male     No  Sun  Dinner     4
# 30016702287574         14.83  3.02  Female     No  Sun  Dinner     2
# 180073029785069        21.58  3.92    Male     No  Sun  Dinner     2
# 4240025044626033       10.33  1.67  Female     No  Sun  Dinner     3
# 6521340257218708       16.29  3.71    Male     No  Sun  Dinner     3
#
#                   price_per_person Payment ID
# CC Number
# 566287581219                  5.14    Sun2546
# 4577817359320969              8.82    Sun6686
# 577040572932                  7.71    Sun1300
# 6011163105616890              4.61    Sun2971
# 30016702287574                7.42    Sun3848
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 3560325168603410 to 3511451626698139
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payment ID        244 non-null    object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 19.1+ KB

# %%
df.sample(5)
# Out:
#                   total_bill   tip     sex smoker   day    time  size  \
# CC Number
# 4317015327600068       19.81  4.19  Female    Yes  Thur   Lunch     2
# 3534021246117605       10.07  1.25    Male     No   Sat  Dinner     2
# 4813617017359506       14.07  2.50    Male     No   Sun  Dinner     2
# 213102478792200        14.52  2.00  Female     No  Thur   Lunch     2
# 4472778228206399       12.48  2.52  Female     No  Thur   Lunch     2
#
#                   price_per_person Payment ID
# CC Number
# 4317015327600068              9.90    Thur967
# 3534021246117605              5.04    Sat4615
# 4813617017359506              7.04    Sun8863
# 213102478792200               7.26   Thur1512
# 4472778228206399              6.24    Thur208

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person
# count  244.000000  244.000000  244.000000        244.000000
# mean    19.785943    2.998279    2.569672          7.888197
# std      8.902412    1.383638    0.951100          2.914234
# min      3.070000    1.000000    1.000000          2.880000
# 25%     13.347500    2.000000    2.000000          5.800000
# 50%     17.795000    2.900000    2.000000          7.255000
# 75%     24.127500    3.562500    3.000000          9.390000
# max     50.810000   10.000000    6.000000         20.270000

# %%
df.describe().T
# Out:
#                   count       mean       std   min      25%     50%      75%  \
# total_bill        244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275
# tip               244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625
# size              244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000
# price_per_person  244.0   7.888197  2.914234  2.88   5.8000   7.255   9.3900
#
#                     max
# total_bill        50.81
# tip               10.00
# size               6.00
# price_per_person  20.27
