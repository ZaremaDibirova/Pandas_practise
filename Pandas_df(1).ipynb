# %%
import numpy as np
import pandas as pd

# %%
my_data=np.random.randint(40,101,(8,4))
my_idx=['Zarema','Ruslan','Islam','Adile','Ayse','Aynure','Nadir','Elvin']
my_col=['Az dili','Riyaziyyat','Ingilis dili','Informatika']
df_new=pd.DataFrame(my_data,index=my_idx,columns=my_col)
df_new
# Out:
#         Az dili  Riyaziyyat  Ingilis dili  Informatika
# Zarema       53         100            69           47
# Ruslan       44          41            53           85
# Islam        61          47            61           46
# Adile        81          47            73           84
# Ayse         55          88            80           62
# Aynure       40          70            85           56
# Nadir        92          47            99           66
# Elvin        41          42            74           88

# %%
df_new.head()
# Out:
#         Az dili  Riyaziyyat  Ingilis dili  Informatika
# Zarema       53         100            69           47
# Ruslan       44          41            53           85
# Islam        61          47            61           46
# Adile        81          47            73           84
# Ayse         55          88            80           62

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, Zarema to Elvin
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Az dili       8 non-null      int64
#  1   Riyaziyyat    8 non-null      int64
#  2   Ingilis dili  8 non-null      int64
#  3   Informatika   8 non-null      int64
# dtypes: int64(4)
# memory usage: 620.0+ bytes

# %%
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 128       11.38  2.00  Female     No  Thur   Lunch     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.shape[1]
# Out:
# 7

# %%
df.shape[0]
# Out:
# 244

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe().transpose()
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df['total_bill'].head()
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
df[['total_bill','tip']].head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
df['Bonkorluk']=df['tip']/df['total_bill']*100

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  Bonkorluk
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
df.drop('Bonkorluk',axis=1).head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  Bonkorluk
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
df.drop('Bonkorluk',axis=1,inplace=True)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.drop(['smoker','day'],axis=1)
# Out:
#      total_bill   tip     sex    time  size
# 0         16.99  1.01  Female  Dinner     2
# 1         10.34  1.66    Male  Dinner     3
# 2         21.01  3.50    Male  Dinner     3
# 3         23.68  3.31    Male  Dinner     2
# 4         24.59  3.61  Female  Dinner     4
# ..          ...   ...     ...     ...   ...
# 239       29.03  5.92    Male  Dinner     3
# 240       27.18  2.00  Female  Dinner     2
# 241       22.67  2.00    Male  Dinner     2
# 242       17.82  1.75    Male  Dinner     2
# 243       18.78  3.00  Female  Dinner     2
#
# [244 rows x 5 columns]

# %%
df.total_bill.head()
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64
